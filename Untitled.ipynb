# %% [markdown]
# # 🎯 Analytical Solution of 1D Attenuated Acoustic Wave Equation
#
# ## 📌 1. Introduction
# Acoustic waves propagate through various media, but real-world materials introduce **attenuation**, causing a gradual loss of wave energy. The **1D attenuated acoustic wave equation** is:
#
#
# $
# \frac{\partial^2 p}{\partial t^2} + \alpha \frac{\partial p}{\partial t} = c^2 \frac{\partial^2 p}{\partial x^2}
# $
#
# where:
# -  p(x,t)  → Acoustic pressure at position \( x \) and time \( t \),
# -  c  → Speed of sound in the medium,
# - $ \alpha \ $→ Attenuation coefficient (controls energy dissipation).
#
# ---
#
# ## 🔍 2. Analytical Solution
# For an **initial Gaussian wave packet**, the analytical solution is:
#
# $
# p(x,t) = e^{-\frac{\alpha}{2} t} \left[ e^{-(x - c t)^2} + e^{-(x + c t)^2} \right]
#  $
#
# where:
# - $  e^{-\frac{\alpha}{2} t}  $ represents the **exponential decay** due to attenuation.
# - $ e^{-(x - c t)^2} $ describes a **right-moving wave**.
# - $ e^{-(x + c t)^2} $ describes a **left-moving wave**.
#
# ---
#
# ## 📌 3. Key Observations
# ✔️ The **wave propagates symmetrically** in both directions.
# ✔️ The **amplitude decreases** over time due to attenuation.
# ✔️ The **Gaussian shape is preserved**, meaning the wave does not distort.
# ✔️ Higher **attenuation $ \alpha $ leads to faster energy loss**.
#
# ---
#
# ## 🏗️ 4. Physical Interpretation
# - In real-world applications such as **ultrasound imaging and medical acoustics**, waves lose energy due to tissue absorption.
# - The **wave propagates**, but its strength diminishes over time.
# - The equation helps model **sound propagation in biological tissues**, making it useful for applications like **tumor detection and therapeutic ultrasound**.
#
# ---

# %%
# Define constants
c = 1.0       # Speed of sound
alpha = 0.5   # Attenuation coefficient
x0 = 0        # Initial wave center

# Define spatial and temporal domains
x = np.linspace(-5, 5, 200)  # Space grid
t = np.linspace(0, 2, 50)    # Time grid

# Create mesh grid for plotting
X, T = np.meshgrid(x, t)

# Compute analytical solution
def analytical_solution(x, t, c=1.0, alpha=0.5):
    return np.exp(-alpha * t / 2) * (np.exp(-(x - c * t)**2) + np.exp(-(x + c * t)**2))

P = analytical_solution(X, T, c, alpha)

# Plot results
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Contour plot of wave propagation
plt.contourf(X, T, P, levels=50, cmap="jet")
plt.colorbar(label="Acoustic Pressure (p)")
plt.xlabel("Position (x)")
plt.ylabel("Time (t)")
plt.title("Analytical Solution of 1D Attenuated Acoustic Wave Equation")
plt.show()

# Line plot for different time steps
plt.figure(figsize=(10, 5))
for t_idx in [0, 10, 20, 30, 40]:  # Select time steps
    plt.plot(x, P[t_idx, :], label=f"t = {t[t_idx]:.2f}")

plt.xlabel("Position (x)")
plt.ylabel("Acoustic Pressure (p)")
plt.title("Wave Propagation Over Time")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 📌 5. Conclusion
# The **1D attenuated acoustic wave equation** models wave behavior in **dissipative media**. The **exponential decay term** ensures that the wave amplitude decreases, while the Gaussian shape remains intact. This is essential in applications like **biomedical imaging, material testing, and geophysics**.
#
# ---

# %%
# !pip install deepxde
import deepxde as dde
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
# !pip install --upgrade scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deepxde in c:\users\ankit\appdata\roaming\python\python312\site-packages (1.13.1)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from deepxde) (3.9.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from deepxde) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from deepxde) (1.5.1)
# Requirement already satisfied: scikit-optimize>=0.9.0 in c:\users\ankit\appdata\roaming\python\python312\site-packages (from deepxde) (0.10.2)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from deepxde) (1.13.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-optimize>=0.9.0->deepxde) (1.4.2)
# Requirement already satisfied: pyaml>=16.9 in c:\users\ankit\appdata\roaming\python\python312\site-packages (from scikit-optimize>=0.9.0->deepxde) (25.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\programdata\anaconda3\lib\site-packages (from scikit-optimize>=0.9.0->deepxde) (24.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->deepxde) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->deepxde) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->deepxde) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->deepxde) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->deepxde) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->deepxde) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->deepxde) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->deepxde) (2.9.0.post0)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\lib\site-packages (from pyaml>=16.9->scikit-optimize>=0.9.0->deepxde) (6.0.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->deepxde) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (1.13.1)
# Collecting scipy
#   Downloading scipy-1.15.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\programdata\anaconda3\lib\site-packages (from scipy) (1.26.4)
# Downloading scipy-1.15.2-cp312-cp312-win_amd64.whl (40.9 MB)
#    ---------------------------------------- 0.0/40.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/40.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/40.9 MB 1.9 MB/s eta 0:00:22
#     --------------------------------------- 0.8/40.9 MB 1.8 MB/s eta 0:00:23
#    - -------------------------------------- 1.3/40.9 MB 1.7 MB/s eta 0:00:24
#    - -------------------------------------- 1.6/40.9 MB 1.7 MB/s eta 0:00:24
#    - -------------------------------------- 1.8/40.9 MB 1.7 MB/s eta 0:00:23
#    -- ------------------------------------- 2.4/40.9 MB 1.7 MB/s eta 0:00:23
#    -- ------------------------------------- 2.6/40.9 MB 1.7 MB/s eta 0:00:23
#    --- ------------------------------------ 3.1/40.9 MB 1.7 MB/s eta 0:00:22
#    --- ------------------------------------ 3.4/40.9 MB 1.8 MB/s eta 0:00:22
#    --- ------------------------------------ 3.9/40.9 MB 1.8 MB/s eta 0:00:22
#    ---- ----------------------------------- 4.2/40.9 MB 1.7 MB/s eta 0:00:22
#    ---- ----------------------------------- 4.5/40.9 MB 1.7 MB/s eta 0:00:21
#    ---- ----------------------------------- 4.7/40.9 MB 1.7 MB/s eta 0:00:22
#    ---- ----------------------------------- 5.0/40.9 MB 1.7 MB/s eta 0:00:22
#    ----- ---------------------------------- 5.2/40.9 MB 1.7 MB/s eta 0:00:22
#    ----- ---------------------------------- 5.8/40.9 MB 1.7 MB/s eta 0:00:22
#    ----- ---------------------------------- 6.0/40.9 MB 1.7 MB/s eta 0:00:22
#    ------ --------------------------------- 6.3/40.9 MB 1.7 MB/s eta 0:00:21
#    ------ --------------------------------- 6.6/40.9 MB 1.6 MB/s eta 0:00:22
#    ------ --------------------------------- 6.8/40.9 MB 1.6 MB/s eta 0:00:21
#    ------ --------------------------------- 7.1/40.9 MB 1.6 MB/s eta 0:00:21
#    ------- -------------------------------- 7.6/40.9 MB 1.6 MB/s eta 0:00:21
#    ------- -------------------------------- 7.9/40.9 MB 1.6 MB/s eta 0:00:21
#    -------- ------------------------------- 8.4/40.9 MB 1.6 MB/s eta 0:00:20
#    -------- ------------------------------- 8.7/40.9 MB 1.6 MB/s eta 0:00:20
#    -------- ------------------------------- 8.9/40.9 MB 1.6 MB/s eta 0:00:20
4 MB/s eta 0:00:09
#    ---------------------------- ----------- 29.4/40.9 MB 1.4 MB/s eta 0:00:09
#    ---------------------------- ----------- 29.6/40.9 MB 1.4 MB/s eta 0:00:09
#    ----------------------------- ---------- 29.9/40.9 MB 1.4 MB/s eta 0:00:09
#    ----------------------------- ---------- 30.1/40.9 MB 1.4 MB/s eta 0:00:08
#    ----------------------------- ---------- 30.4/40.9 MB 1.4 MB/s eta 0:00:08
#    ----------------------------- ---------- 30.7/40.9 MB 1.4 MB/s eta 0:00:08
#    ------------------------------ --------- 30.9/40.9 MB 1.4 MB/s eta 0:00:08
#    ------------------------------ --------- 31.2/40.9 MB 1.4 MB/s eta 0:00:08
#    ------------------------------ --------- 31.5/40.9 MB 1.4 MB/s eta 0:00:07
#    ------------------------------ --------- 31.7/40.9 MB 1.4 MB/s eta 0:00:07
#    ------------------------------- -------- 32.0/40.9 MB 1.4 MB/s eta 0:00:07
#    ------------------------------- -------- 32.0/40.9 MB 1.4 MB/s eta 0:00:07
#    ------------------------------- -------- 32.2/40.9 MB 1.4 MB/s eta 0:00:07
#    ------------------------------- -------- 32.5/40.9 MB 1.4 MB/s eta 0:00:07
#    -------------------------------- ------- 32.8/40.9 MB 1.4 MB/s eta 0:00:07
#    -------------------------------- ------- 33.0/40.9 MB 1.4 MB/s eta 0:00:06
#    -------------------------------- ------- 33.3/40.9 MB 1.4 MB/s eta 0:00:06
#    -------------------------------- ------- 33.6/40.9 MB 1.4 MB/s eta 0:00:06
#    --------------------------------- ------ 33.8/40.9 MB 1.4 MB/s eta 0:00:06
#    --------------------------------- ------ 34.1/40.9 MB 1.4 MB/s eta 0:00:06
#    --------------------------------- ------ 34.3/40.9 MB 1.3 MB/s eta 0:00:05
#    --------------------------------- ------ 34.3/40.9 MB 1.3 MB/s eta 0:00:05
#    --------------------------------- ------ 34.3/40.9 MB 1.3 MB/s eta 0:00:05
#    --------------------------------- ------ 34.6/40.9 MB 1.3 MB/s eta 0:00:05
#    ---------------------------------- ----- 34.9/40.9 MB 1.3 MB/s eta 0:00:05
#    ---------------------------------- ----- 35.4/40.9 MB 1.3 MB/s eta 0:00:05
#    ---------------------------------- ----- 35.7/40.9 MB 1.3 MB/s eta 0:00:04
#    ----------------------------------- ---- 35.9/40.9 MB 1.3 MB/s eta 0:00:04
#    ----------------------------------- ---- 36.2/40.9 MB 1.3 MB/s eta 0:00:04
#    ----------------------------------- ---- 36.4/40.9 MB 1.3 MB/s eta 0:00:04
#    ----------------------------------- ---- 36.7/40.9 MB 1.3 MB/s eta 0:00:04
#    ------------------------------------ --- 37.0/40.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------ --- 37.2/40.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------ --- 37.5/40.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------ --- 37.7/40.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------- -- 38.3/40.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------- -- 38.3/40.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------- -- 38.5/40.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------- -- 38.8/40.9 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 39.1/40.9 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 39.3/40.9 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 39.6/40.9 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 39.8/40.9 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.9 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  40.4/40.9 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  40.6/40.9 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 40.9/40.9 MB 1.3 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.15.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.2 which is incompatible.

# %%
from scipy.stats.qmc import Sobol

# %%
from IPython.display import FileLink

# %%
# Set random seed for reproducibility
dde.config.set_random_seed(42)

# Define constants
c = 1.0       # Speed of sound
alpha = 0.5   # Attenuation coefficient

# Define the PDE
def pde(x, p):
    dp_t = dde.grad.jacobian(p, x, i=0, j=1)          # ∂p/∂t
    dp_tt = dde.grad.hessian(p, x, i=0, j=1)           # ∂²p/∂t²
    dp_xx = dde.grad.hessian(p, x, i=0, j=0)           # ∂²p/∂x²
    return dp_tt - c**2 * dp_xx + alpha * dp_t

# Analytical solution for comparison
def analytical_solution(x, t, c=1.0, alpha=0.5):
    return np.exp(-alpha * t / 2) * (np.exp(-(x - c * t)**2) + np.exp(-(x + c * t)**2))

# Initial condition p(x, 0) = exp(-x^2)
def ic_func(x):
    return np.exp(-x**2)

# Initial condition and boundary condition
geom = dde.geometry.Interval(-5, 5)
timedomain = dde.geometry.TimeDomain(0, 2)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

# ic = dde.IC(geomtime, ic_func, lambda _, on_initial: on_initial)
ic = dde.IC(geomtime, lambda x: np.zeros((len(x), 1)), lambda _, on_initial: on_initial)

bc = dde.DirichletBC(geomtime, lambda x: 0, lambda _, on_boundary: on_boundary)

# Data setup
data = dde.data.TimePDE(
    geomtime,
    pde,
    [ic, bc],
    num_domain=4000,
    num_boundary=100,
    num_initial=100,
    train_distribution="uniform",
)

# Neural network
net = dde.maps.FNN([2] + [50] * 3 + [1], "tanh", "Glorot uniform")

# PINN model
model = dde.Model(data, net)

# Compile and train the model
model.compile("adam", lr=1e-3)
losshistory, train_state = model.train(epochs=5000)

# Plot loss history
dde.utils.plot_loss_history(losshistory)
plt.title("Training Loss History")
plt.show()

# Prediction
x = np.linspace(-5, 5, 200)
t = np.linspace(0, 2, 50)
X, T = np.meshgrid(x, t)
X_flat = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

p_pred = model.predict(X_flat).reshape(X.shape)
p_true = analytical_solution(X, T, c, alpha)

# Plotting predicted solution
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
plt.contourf(X, T, p_pred, levels=50, cmap="jet")
plt.colorbar(label="Acoustic Pressure (p)")
plt.xlabel("Position (x)")
plt.ylabel("Time (t)")
plt.title("PINN Solution of 1D Attenuated Acoustic Wave Equation")
plt.show()


# Plotting analytical solution
plt.figure(figsize=(12, 6))
plt.contourf(X, T, p_true, levels=50, cmap="jet")
plt.colorbar(label="Acoustic Pressure (p)")
plt.xlabel("Position (x)")
plt.ylabel("Time (t)")
plt.title("Analytical Solution of 1D Attenuated Acoustic Wave Equation")
plt.show()

# Comparison plot for specific time steps
plt.figure(figsize=(10, 6))
for t_idx in [0, 10, 20, 30, 40]:
    plt.plot(x, p_pred[t_idx, :], label=f"Predicted (t = {t[t_idx]:.2f})", linestyle="--")
    plt.plot(x, p_true[t_idx, :], label=f"Analytical (t = {t[t_idx]:.2f})", linestyle="-")
plt.xlabel("Position (x)")
plt.ylabel("Acoustic Pressure (p)")
plt.title("Comparison of PINN and Analytical Solutions at Different Time Steps")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Warning: 4000 points required, but 4118 points sampled.
# Compiling model...
# 'compile' took 0.000092 s
#
# Warning: epochs is deprecated and will be removed in a future version. Use iterations instead.
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [7.17e-03, 8.92e-02, 2.19e-01]    [7.17e-03, 8.92e-02, 2.19e-01]    []
# 1000      [2.49e-06, 3.02e-07, 2.89e-07]    [2.49e-06, 3.02e-07, 2.89e-07]    []
# 2000      [7.75e-07, 4.68e-08, 8.11e-08]    [7.75e-07, 4.68e-08, 8.11e-08]    []
# 3000      [1.25e-06, 4.21e-05, 7.86e-05]    [1.25e-06, 4.21e-05, 7.86e-05]    []
# 4000      [1.78e-07, 2.48e-08, 5.60e-09]    [1.78e-07, 2.48e-08, 5.60e-09]    []
# 5000      [1.04e-07, 7.60e-09, 9.98e-10]    [1.04e-07, 7.60e-09, 9.98e-10]    []
#
# Best model at step 5000:
#   train loss: 1.12e-07
#   test loss: 1.12e-07
#   test metric: []
#
# 'train' took 131.798411 s
